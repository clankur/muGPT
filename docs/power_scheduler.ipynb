# %%
from plot_helper import *

# %%
chinchilla_optimal_ids = [
    "1629fa3c62d54f889db2f69f08caaffb", # 2900 steps
    "6ba12ef81cb44fc7bc5b44abe38a67c0"
]
chinchilla_optimal_configs = get_configs(chinchilla_optimal_ids)
chinchilla_optimal_loss = get_loss_data(chinchilla_optimal_ids)
plot_loss_data(chinchilla_optimal_loss, plot_last=1000)
for data in chinchilla_optimal_configs.values(): 
    print(data['name'], '\n-------') 
    print(data['config'])
# Out:
# c4_a100x8x4_37m_power_scheduler_steps=2900
# -------
# model:
#   a_attn: 1.0
#   a_output: 1.0
#   base:
#     d_ff: 2048
#     d_head: 64
#     d_model: 256
#     layers: 8
#     n_kv: 16
#     n_q_per_kv: 1
#   d_ff: 2048
#   d_head: 64
#   d_model: 256
#   layers: 8
#   n_kv: 16
#   n_q_per_kv: 1
#   rope_max_timescale: 10000
#   vocab: 32768
#   zero_queries: true
#   zero_unembed: true
# training:
#   adam_b1: 0.9
#   adam_b2: 0.95
#   adam_eps: 1.0e-08
#   adam_eps_root: 0.0
#   amplitude: 2.4929835408416423
#   cosine_learning_rate_final_fraction: 0.1
#   learning_rate: 0.02
#   power_law_exp: -0.6102458825048835
#   queue: v4-32
#   seed: 0
#   steps: 2900
#   tokens:
#     batch: 256
#     len: 1024
#   use_grad_clip: true
#   warmup_steps: 290
#   weight_decay: 0.1
#
# c4_a100x8x4_37m
# -------
# model:
#   a_attn: 1.0
#   a_output: 1.0
#   base:
#     d_ff: 2048
#     d_head: 64
#     d_model: 256
#     layers: 8
#     n_kv: 16
#     n_q_per_kv: 1
#   d_ff: 2048
# ...

# %%
double_chinchilla_optimal_ids = [
    "0d159979bbeb471291af6cb8a31951c1",
    "f5f7ad5e1f924b0d8059f8d146881184",
]
chinchilla_optimal_configs = get_configs(double_chinchilla_optimal_ids)
double_chinchilla_optimal_loss = get_loss_data(double_chinchilla_optimal_ids)
plot_loss_data(double_chinchilla_optimal_loss, plot_last=1000)
for data in chinchilla_optimal_configs.values(): 
    print(data['name'], '\n-------') 
    print(data['config'])
# Out:
# c4_a100x8x4_37m_power_scheduler.training.steps:5800
# -------
# model:
#   a_attn: 1.0
#   a_output: 1.0
#   base:
#     d_ff: 2048
#     d_head: 64
#     d_model: 256
#     layers: 8
#     n_kv: 16
#     n_q_per_kv: 1
#   d_ff: 2048
#   d_head: 64
#   d_model: 256
#   layers: 8
#   n_kv: 16
#   n_q_per_kv: 1
#   rope_max_timescale: 10000
#   vocab: 32768
#   zero_queries: true
#   zero_unembed: true
# training:
#   adam_b1: 0.9
#   adam_b2: 0.95
#   adam_eps: 1.0e-08
#   adam_eps_root: 0.0
#   amplitude: 2.4929835408416423
#   cosine_learning_rate_final_fraction: 0.1
#   learning_rate: 0.02
#   power_law_exp: -0.6102458825048835
#   queue: v4-32
#   seed: 0
#   steps: 5800
#   tokens:
#     batch: 256
#     len: 1024
#   use_grad_clip: true
#   warmup_steps: 580
#   weight_decay: 0.1
#
# c4_a100x8x4_37m_cosine_annealing_scheduler_training.steps:5800
# -------
# model:
#   a_attn: 1.0
#   a_output: 1.0
#   base:
#     d_ff: 2048
#     d_head: 64
#     d_model: 256
#     layers: 8
# ...

# %%
x4_chinchilla_optimal_ids = [
    "2069ee15edd44fa3a8a5b5a8b5dc6865",
    "dcc0665be34843e4af896e6b4f7fcbf5",
]
x4_chinchilla_optimal_configs = get_configs(x4_chinchilla_optimal_ids)
x4_chinchilla_optimal_loss = get_loss_data(x4_chinchilla_optimal_ids)
plot_loss_data(x4_chinchilla_optimal_loss, plot_last=1000)
for data in x4_chinchilla_optimal_configs.values(): 
    print(data['name'], '\n-------') 
    print(data['config'])
# Out:
# c4_a100x8x4_37m_power_scheduler_training.steps:11600
# -------
# model:
#   a_attn: 1.0
#   a_output: 1.0
#   base:
#     d_ff: 2048
#     d_head: 64
#     d_model: 256
#     layers: 8
#     n_kv: 16
#     n_q_per_kv: 1
#   d_ff: 2048
#   d_head: 64
#   d_model: 256
#   layers: 8
#   n_kv: 16
#   n_q_per_kv: 1
#   rope_max_timescale: 10000
#   vocab: 32768
#   zero_queries: true
#   zero_unembed: true
# training:
#   adam_b1: 0.9
#   adam_b2: 0.95
#   adam_eps: 1.0e-08
#   adam_eps_root: 0.0
#   amplitude: 2.4929835408416423
#   cosine_learning_rate_final_fraction: 0.1
#   learning_rate: 0.02
#   power_law_exp: -0.6102458825048835
#   queue: v4-32
#   seed: 0
#   steps: 11600
#   tokens:
#     batch: 256
#     len: 1024
#   use_grad_clip: true
#   warmup_steps: 1160
#   weight_decay: 0.1
#
# c4_a100x8x4_37m_training.steps:11600,training.steps_for_lr:11600,training.warmup_steps:1160
# -------
# model:
#   a_attn: 1.0
#   a_output: 1.0
#   base:
#     d_ff: 2048
#     d_head: 64
# ...
